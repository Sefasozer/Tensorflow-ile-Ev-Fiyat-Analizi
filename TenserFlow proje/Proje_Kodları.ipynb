# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_csv("kc_house_data.csv")

# %%
dataFrame
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
dataFrame.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataFrame.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])

# %%
dataFrame.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x = "bedrooms", y= "price", data = dataFrame)

# %%
dataFrame.sort_values("price",ascending = False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
dataFrame.sort_values("price",ascending = True).head(20)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
# 2141   1623049041  20140508T000000  82500.0         2       1.00          520
# 18468  7999600180  20140529T000000  83000.0         2       1.00          900
# 3767   1523049188  20150430T000000  84000.0         2       1.00          700
# 16714  1322049150  20150305T000000  85000.0         2       1.00          910
# 10253  2422049104  20140915T000000  85000.0         2       1.00          830
# 13756  1788900230  20140722T000000  86500.0         3       1.00          840
# ...

# %%
len(dataFrame)
# Out:
# 21613

# %%
yuzdeDoksanDokuzDf = dataFrame.sort_values("price",ascending = False).iloc[132:]

# %%
plt.figure(figsize  = (7,5))
sbn.distplot(yuzdeDoksanDokuzDf["price"])

# %%
dataFrame.groupby("yr_built").mean()["price"]
# Out:
# yr_built
# 1900    581387.206897
# 1901    556935.931034
# 1902    673007.407407
# 1903    480958.195652
# 1904    583756.644444
#             ...
# 2011    544522.000000
# 2012    527447.335294
# 2013    678545.452736
# 2014    683681.754919
# 2015    759785.157895
# Name: price, Length: 116, dtype: float64

# %%
yuzdeDoksanDokuzDf.groupby("yr_built").mean()["price"]
# Out:
# yr_built
# 1900    581387.206897
# 1901    556935.931034
# 1902    673007.407407
# 1903    480958.195652
# 1904    522023.840909
#             ...
# 2011    528781.860465
# 2012    527447.335294
# 2013    646654.727273
# 2014    668571.785586
# 2015    759785.157895
# Name: price, Length: 116, dtype: float64

# %%
yuzdeDoksanDokuzDf
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16258  1652500010  20150326T000000  2328000.0         4       3.50
# 20664  4139300135  20140709T000000  2321000.0         5       4.75
# 19823  8085400376  20150421T000000  2320000.0         4       3.50
# 13020  1118001201  20150130T000000  2300000.0         4       2.50
# 11402  3426049284  20140819T000000  2300000.0         4       3.25
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16258         4420     20759     2.0           0     0  ...     11
# ...

# %%
dataFrame = yuzdeDoksanDokuzDf

# %%
dataFrame = dataFrame[dataFrame.yr_built != 1900]

# %%
dataFrame.groupby("yr_built").mean()["price"]
# Out:
# yr_built
# 1901    556935.931034
# 1902    673007.407407
# 1903    480958.195652
# 1904    522023.840909
# 1905    752977.986486
#             ...
# 2011    528781.860465
# 2012    527447.335294
# 2013    646654.727273
# 2014    668571.785586
# 2015    759785.157895
# Name: price, Length: 115, dtype: float64

# %%
dataFrame.head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16258  1652500010  20150326T000000  2328000.0         4       3.50
# 20664  4139300135  20140709T000000  2321000.0         5       4.75
# 19823  8085400376  20150421T000000  2320000.0         4       3.50
# 13020  1118001201  20150130T000000  2300000.0         4       2.50
# 11402  3426049284  20140819T000000  2300000.0         4       3.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16258         4420     20759     2.0           0     0  ...     11
# 20664         5780     17004     2.0           0     0  ...     11
# 19823         5050      9520     2.0           0     0  ...     11
# 13020         3370      8402     1.0           0     0  ...     10
# 11402         4110     15929     2.0           1     4  ...     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 16258        4420              0      2003             0    98004  47.6354
# ...

# %%
dataFrame = dataFrame.drop("date" , axis = 1)

# %%
dataFrame
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16258  1652500010  2328000.0         4       3.50         4420     20759
# 20664  4139300135  2321000.0         5       4.75         5780     17004
# 19823  8085400376  2320000.0         4       3.50         5050      9520
# 13020  1118001201  2300000.0         4       2.50         3370      8402
# 11402  3426049284  2300000.0         4       3.25         4110     15929
# ...           ...        ...       ...        ...          ...       ...
# 8274   3883800011    82000.0         3       1.00          860     10426
# 16198  3028200080    81000.0         2       1.00          730      9975
# 465    8658300340    80000.0         1       0.75          430      5050
# 15293    40000362    78000.0         2       1.00          780     16344
# 1149   3421079032    75000.0         1       0.00          670     43377
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
y = dataFrame["price"].values
x = dataFrame.drop("price",axis = 1).values

# %%
y
# Out:
# array([2328000., 2321000., 2320000., ...,   80000.,   78000.,   75000.])

# %%
x
# Out:
# array([[ 1.65250001e+09,  4.00000000e+00,  3.50000000e+00, ...,
#         -1.22221000e+02,  3.02000000e+03,  2.06660000e+04],
#        [ 4.13930014e+09,  5.00000000e+00,  4.75000000e+00, ...,
#         -1.22212000e+02,  3.46000000e+03,  1.08550000e+04],
#        [ 8.08540038e+09,  4.00000000e+00,  3.50000000e+00, ...,
#         -1.22209000e+02,  2.43000000e+03,  9.24800000e+03],
#        ...,
#        [ 8.65830034e+09,  1.00000000e+00,  7.50000000e-01, ...,
#         -1.21909000e+02,  1.20000000e+03,  7.50000000e+03],
#        [ 4.00003620e+07,  2.00000000e+00,  1.00000000e+00, ...,
#         -1.22280000e+02,  1.70000000e+03,  1.03870000e+04],
#        [ 3.42107903e+09,  1.00000000e+00,  0.00000000e+00, ...,
#         -1.21906000e+02,  1.16000000e+03,  4.28820000e+04]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size = 0.3)

# %%
len(x_train)
# Out:
# 14975

# %%
len(x_test)
# Out:
# 6419

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (14975, 19)

# %%
model = Sequential()

model.add(Dense(50,activation = "relu"))
model.add(Dense(50,activation = "relu"))
model.add(Dense(50,activation = "relu"))
model.add(Dense(50,activation = "relu"))
model.add(Dense(50,activation = "relu"))
model.add(Dense(50,activation = "relu"))

model.add(Dense(1))
model.compile(optimizer = "adam",loss = "mse")

# %%
model.fit(x = x_train, y= y_train,validation_data = (x_test,y_test),batch_size = 350,epochs = 450)
# Out:
# Epoch 1/450
# 43/43 [==============================] - 1s 7ms/step - loss: 369187028992.0000 - val_loss: 359114276864.0000
# Epoch 2/450
# 43/43 [==============================] - 0s 4ms/step - loss: 368002891776.0000 - val_loss: 353247428608.0000
# Epoch 3/450
# 43/43 [==============================] - 0s 4ms/step - loss: 309538226176.0000 - val_loss: 169955524608.0000
# Epoch 4/450
# 43/43 [==============================] - 0s 4ms/step - loss: 82144706560.0000 - val_loss: 61094920192.0000
# Epoch 5/450
# 43/43 [==============================] - 0s 4ms/step - loss: 62742495232.0000 - val_loss: 57986859008.0000
# Epoch 6/450
# 43/43 [==============================] - 0s 4ms/step - loss: 60002648064.0000 - val_loss: 55266381824.0000
# Epoch 7/450
# 43/43 [==============================] - 0s 4ms/step - loss: 57340821504.0000 - val_loss: 52663214080.0000
# Epoch 8/450
# 43/43 [==============================] - 0s 4ms/step - loss: 54625611776.0000 - val_loss: 50092580864.0000
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#            loss      val_loss
# 0  3.691870e+11  3.591143e+11
# 1  3.680029e+11  3.532474e+11
# 2  3.095382e+11  1.699555e+11
# 3  8.214471e+10  6.109492e+10
# 4  6.274250e+10  5.798686e+10

# %%
kayipVerisi.plot()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)

# %%
tahminDizisi
# Out:
# array([[558681.9 ],
#        [230667.3 ],
#        [380306.94],
#        ...,
#        [663608.75],
#        [469768.7 ],
#        [483877.3 ]], dtype=float32)

# %%
mean_absolute_error(y_test,tahminDizisi)
# Out:
# 66260.3437378291

# %%
dataFrame
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16258  1652500010  2328000.0         4       3.50         4420     20759
# 20664  4139300135  2321000.0         5       4.75         5780     17004
# 19823  8085400376  2320000.0         4       3.50         5050      9520
# 13020  1118001201  2300000.0         4       2.50         3370      8402
# 11402  3426049284  2300000.0         4       3.25         4110     15929
# ...           ...        ...       ...        ...          ...       ...
# 8274   3883800011    82000.0         3       1.00          860     10426
# 16198  3028200080    81000.0         2       1.00          730      9975
# 465    8658300340    80000.0         1       0.75          430      5050
# 15293    40000362    78000.0         2       1.00          780     16344
# 1149   3421079032    75000.0         1       0.00          670     43377
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
dataFrame.iloc[:2]
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16258  1652500010  2328000.0         4       3.50         4420     20759
# 20664  4139300135  2321000.0         5       4.75         5780     17004
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 16258     2.0           0     0          3     11        4420              0
# 20664     2.0           0     0          3     11        4260           1520
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 16258      2003             0    98004  47.6354 -122.221           3020
# 20664      2006             0    98040  47.5802 -122.212           3460
#
#        sqft_lot15
# 16258       20666
# 20664       10855

# %%
yeniEvSeries = dataFrame.drop("price",axis = 1).iloc[2]

# %%
yeniEvSeries = scaler.transform(yeniEvSeries.values.reshape(-1,19))

# %%
model.predict(yeniEvSeries)
# Out:
# array([[2117400.8]], dtype=float32)
